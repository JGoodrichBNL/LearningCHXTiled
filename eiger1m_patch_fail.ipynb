# %%
import numpy as np
import matplotlib.pyplot as plt
import time
    
from tiled.client import from_profile
c = from_profile("chx", "dask")
from databroker.queries import TimeRange
results = c.search(TimeRange(since="2021-08"))
# Out:
# OBJECT CACHE: Will use up to 121_695_745_228 bytes (15% of total physical RAM)

# %%
id = [[59832, 'eiger1m_single_image'], [59900, 'eiger1m_single_image'], [62239, 'eiger4m_single_image']]

# %%
starttime = time.time() # id = 59832, Eiger 1m image
img = results[id[0][0]]['primary'].read()[id[0][1]][0,0]
img.compute()
#plt.imshow(img,vmax=1000)
elaptime = time.time()-starttime
print("%.1f sec"%elaptime)
# Out:
# ---------------------------------------------------------------------------
# WouldBlock                                Traceback (most recent call last)
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/anyio/streams/memory.py:81, in MemoryObjectReceiveStream.receive(self)
#      80 try:
# ---> 81     return self.receive_nowait()
#      82 except WouldBlock:
#      83     # Add ourselves in the queue
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/anyio/streams/memory.py:76, in MemoryObjectReceiveStream.receive_nowait(self)
#      74     raise EndOfStream
# ---> 76 raise WouldBlock
#
# WouldBlock:
#
# During handling of the above exception, another exception occurred:
#
# EndOfStream                               Traceback (most recent call last)
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/starlette/middleware/base.py:43, in BaseHTTPMiddleware.__call__.<locals>.call_next(request)
#      42 try:
# ...
